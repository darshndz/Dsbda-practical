# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\NMIET\Downloads\archive\Student_performance_data _.csv")
df
# Out:
#     StudentID      Age   Gender  Ethnicity  ParentalEducation  \
# 0        2005       15      NaN          2                  4
# 1        1197       16      1.0        -20                  4
# 2        3343       15      0.0          0                999
# 3        2709  Unknown      1.0          1                  2
# 4        1436       18      NaN          0                  0
# 5        1322       15      1.0        -20                  1
# 6        2473       15  Unknown          0                999
# 7        2704  Unknown      0.0          0                  1
# 8        1901       15      NaN          0                  1
# 9        1901       15      NaN          0                  1
# 10       3214       17      1.0          2                999
# 11       1576  Unknown      0.0          1                  2
# 12       2164       16      NaN          1                  0
# 13       3315       17      1.0        -20                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          15 non-null     int64
#  1   Age                15 non-null     object
#  2   Gender             10 non-null     object
#  3   Ethnicity          15 non-null     int64
#  4   ParentalEducation  15 non-null     int64
#  5   StudyTimeWeekly    14 non-null     float64
#  6   Absences           15 non-null     int64
#  7   Tutoring           15 non-null     object
#  8   ParentalSupport    15 non-null     int64
#  9   Extracurricular    15 non-null     int64
#  10  Sports             15 non-null     int64
#  11  Music              15 non-null     int64
#  12  Volunteering       15 non-null     int64
#  13  GPA                14 non-null     float64
#  14  GradeClass         15 non-null     float64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 1.9+ KB

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               5
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      1
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  1
# GradeClass           0
# dtype: int64

# %%
df.describe()
# Out:
#          StudentID  Ethnicity  ParentalEducation  StudyTimeWeekly    Absences  \
# count    15.000000  15.000000          15.000000        14.000000   15.000000
# mean   2191.466667  -3.466667         267.533333        25.424055   78.066667
# std     730.862296   8.584593         456.574023        50.486587  254.941861
# min    1197.000000 -20.000000           0.000000         0.135763  -10.000000
# 25%    1594.000000   0.000000           1.000000        10.687256    8.500000
# 50%    2005.000000   0.000000           2.000000        12.976462   13.000000
# 75%    2706.500000   1.000000         501.500000        16.081853   20.000000
# max    3343.000000   2.000000         999.000000       200.000000  999.000000
#
#        ParentalSupport  Extracurricular     Sports      Music  Volunteering  \
# count        15.000000        15.000000  15.000000  15.000000     15.000000
# mean          2.333333         0.533333   0.400000   0.266667      0.200000
# ...

# %%
import numpy as np

# %%
df["Gender"] = df["Gender"].replace("Unknown", np.nan)

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\NMIET\Downloads\archive\Student_performance_data _.csv")
df
# Out:
#     StudentID      Age   Gender  Ethnicity  ParentalEducation  \
# 0        2005       15      NaN          2                  4
# 1        1197       16      1.0        -20                  4
# 2        3343       15      0.0          0                999
# 3        2709  Unknown      1.0          1                  2
# 4        1436       18      NaN          0                  0
# 5        1322       15      1.0        -20                  1
# 6        2473       15  Unknown          0                999
# 7        2704  Unknown      0.0          0                  1
# 8        1901       15      NaN          0                  1
# 9        1901       15      NaN          0                  1
# 10       3214       17      1.0          2                999
# 11       1576  Unknown      0.0          1                  2
# 12       2164       16      NaN          1                  0
# 13       3315       17      1.0        -20                  1
# ...

# %%
df["Gender"] = df["Gender"].replace("Unknown", None)

# %%
df["Age"].value_counts(dropna=False)
# Out:
# 15         6
# 16         3
# Unknown    3
# 17         2
# 18         1
# Name: Age, dtype: int64

# %%
df["Age"] = df["Age"].replace("Unknown", np.nan)

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df["Age"] = df["Age"].astype(int)

# %%
df["Age"].dtype
df["Age"].isnull().sum()
df["Age"].unique()
# Out:
# array([15, 16, 18, 17])

# %%
df
# Out:
#     StudentID  Age   Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        2005   15      NaN          2                  4         0.135763
# 1        1197   16      1.0        -20                  4              NaN
# 2        3343   15      0.0          0                999        10.588715
# 3        2709   15      1.0          1                  2        16.208658
# 4        1436   18      NaN          0                  0       200.000000
# 5        1322   15      1.0        -20                  1        17.006354
# 6        2473   15  Unknown          0                999        14.372075
# 7        2704   15      0.0          0                  1         4.286001
# 8        1901   15      NaN          0                  1        12.190570
# 9        1901   15      NaN          0                  1        12.190570
# 10       3214   17      1.0          2                999        10.982880
# ...

# %%
df["Gender"].value_counts(dropna=False)
# Out:
# 1.0        6
# NaN        5
# 0.0        3
# Unknown    1
# Name: Gender, dtype: int64

# %%
df["Gender"] = df["Gender"].replace("Unknown", np.nan)

# %%
df["Gender"] = pd.to_numeric(df["Gender"], errors="coerce")

# %%
df["Gender"].fillna(df["Gender"].mode()[0], inplace=True)

# %%
df["Gender"].fillna(1, inplace=True)

# %%
df["Gender"] = df["Gender"].astype(int)

# %%
df["Gender"].value_counts()
df["Gender"].isnull().sum()
df["Gender"].dtype
# Out:
# dtype('int32')

# %%
df["Gender_Label"] = df["Gender"].map({0: "Female", 1: "Male"})

# %%
df
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        2005   15       1          2                  4         0.135763
# 1        1197   16       1        -20                  4              NaN
# 2        3343   15       0          0                999        10.588715
# 3        2709   15       1          1                  2        16.208658
# 4        1436   18       1          0                  0       200.000000
# 5        1322   15       1        -20                  1        17.006354
# 6        2473   15       1          0                999        14.372075
# 7        2704   15       0          0                  1         4.286001
# 8        1901   15       1          0                  1        12.190570
# 9        1901   15       1          0                  1        12.190570
# 10       3214   17       1          2                999        10.982880
# 11       1576   15       0          1                  2        13.762353
# ...

# %%
df.drop("Ethnicity", axis=1, inplace=True)

# %%
df
# Out:
#     StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0        2005   15       1                  4         0.135763        17
# 1        1197   16       1                  4              NaN         0
# 2        3343   15       0                999        10.588715        15
# 3        2709   15       1                  2        16.208658       -10
# 4        1436   18       1                  0       200.000000        27
# 5        1322   15       1                  1        17.006354       999
# 6        2473   15       1                999        14.372075        23
# 7        2704   15       0                  1         4.286001        14
# 8        1901   15       1                  1        12.190570        13
# 9        1901   15       1                  1        12.190570        13
# 10       3214   17       1                999        10.982880        10
# 11       1576   15       0                  2        13.762353        25
# ...

# %%
df.drop(["GPA"], axis=1, inplace=True)

# %%
df
# Out:
#     StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0        2005   15       1                  4         0.135763        17
# 1        1197   16       1                  4              NaN         0
# 2        3343   15       0                999        10.588715        15
# 3        2709   15       1                  2        16.208658       -10
# 4        1436   18       1                  0       200.000000        27
# 5        1322   15       1                  1        17.006354       999
# 6        2473   15       1                999        14.372075        23
# 7        2704   15       0                  1         4.286001        14
# 8        1901   15       1                  1        12.190570        13
# 9        1901   15       1                  1        12.190570        13
# 10       3214   17       1                999        10.982880        10
# 11       1576   15       0                  2        13.762353        25
# ...

# %%
df["ParentalEducation"] = df["ParentalEducation"].replace(999, df["ParentalEducation"].mode()[0])

# %%
df["ParentalEducation"].value_counts()
# Out:
# 1    9
# 4    2
# 2    2
# 0    2
# Name: ParentalEducation, dtype: int64

# %%
df
# Out:
#     StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0        2005   15       1                  4         0.135763        17
# 1        1197   16       1                  4              NaN         0
# 2        3343   15       0                  1        10.588715        15
# 3        2709   15       1                  2        16.208658       -10
# 4        1436   18       1                  0       200.000000        27
# 5        1322   15       1                  1        17.006354       999
# 6        2473   15       1                  1        14.372075        23
# 7        2704   15       0                  1         4.286001        14
# 8        1901   15       1                  1        12.190570        13
# 9        1901   15       1                  1        12.190570        13
# 10       3214   17       1                  1        10.982880        10
# 11       1576   15       0                  2        13.762353        25
# ...

# %%
df["StudyTimeWeekly"] = df["StudyTimeWeekly"].clip(lower=0, upper=40)
df["StudyTimeWeekly"].fillna(df["StudyTimeWeekly"].median(), inplace=True)

# %%
df["StudyTimeWeekly"].describe()
# Out:
# count    15.000000
# mean     13.927549
# std       8.634383
# min       0.135763
# 25%      10.785798
# 50%      12.976462
# 75%      15.955048
# max      40.000000
# Name: StudyTimeWeekly, dtype: float64

# %%
df
# Out:
#     StudentID  Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# 0        2005   15       1                  4         0.135763        17
# 1        1197   16       1                  4        12.976462         0
# 2        3343   15       0                  1        10.588715        15
# 3        2709   15       1                  2        16.208658       -10
# 4        1436   18       1                  0        40.000000        27
# 5        1322   15       1                  1        17.006354       999
# 6        2473   15       1                  1        14.372075        23
# 7        2704   15       0                  1         4.286001        14
# 8        1901   15       1                  1        12.190570        13
# 9        1901   15       1                  1        12.190570        13
# 10       3214   17       1                  1        10.982880        10
# 11       1576   15       0                  2        13.762353        25
# ...
